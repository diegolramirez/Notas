# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def eq(x):
    return(1/(2*np.tanh(1/(2*x))))

# %%
def ecl(x):
    return(x)

# %%
#tamañano de imagen y letra
n = 8

# %%
x1 = np.linspace(0,3,500)
y1 = eq(x1)
y2 = ecl(x1)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:2: RuntimeWarning: divide by zero encountered in true_divide
#   from ipykernel import kernelapp as app

# %%
plt.figure(figsize=(8,int(n*(5/8))))
plt.plot(x1,y1,c='r')
plt.title('Energía Cuántica',size=int(n/8*20))
plt.xlim(0,3)
plt.xlabel(r'$\frac{K_BT}{\hbar\omega}$',size=int(n/8*20))
plt.ylabel(r'$\epsilon_q$',size=int(n/8*20))
plt.text(1.5,1,r'$\hbar=\omega=K_B=N=1$',size=int(n/8*20))
plt.savefig("eq.png",bbox_inches='tight')

# %%
plt.figure(figsize=(8,int(n*(5/8))))
plt.plot(x1,y2,c='r')
plt.title('Energía Clásica',size=int(n/8*20))
plt.xlim(0,3)
plt.xlabel(r'$\frac{K_BT}{\hbar\omega}$',size=int(n/8*20))
plt.ylabel(r'$\epsilon_{cl}$',size=int(n/8*20))
plt.text(1.5,1,r'$\hbar=\omega=K_B=N=1$',size=int(n/8*20))
plt.savefig("ecl.png",bbox_inches='tight')

# %%
def cvq(x):
    return ((1/x**2)*(np.exp(1/x)/(np.exp(1/x) - 1)**2))

# %%
def cvcl(x):
    return (np.ones_like(x))

# %%
y3 = cvq(x1)
y4 = cvcl(x1)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:2: RuntimeWarning: divide by zero encountered in true_divide
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:2: RuntimeWarning: invalid value encountered in true_divide
#   from ipykernel import kernelapp as app

# %%
plt.figure(figsize=(8,int(n*(5/8))))
plt.plot(x1,y3,c='r')
plt.title('Capacidad Calorífica Cuántica',size=int(n/8*20))
plt.xlim(0,3)
plt.xlabel(r'$\frac{K_BT}{\hbar\omega}$',size=int(n/8*20))
plt.ylabel(r'$C_V^{q}$',size=int(n/8*20))
plt.text(1.5,0.2,r'$\hbar=\omega=K_B=N=1$',size=int(n/8*20))
plt.savefig("cvcl.png",bbox_inches='tight')

# %%
plt.figure(figsize=(8,int(n*(5/8))))
plt.plot(x1,y4,c='r')
plt.title('Capacidad Calorífica Clásica',size=int(n/8*20))
plt.xlim(0,3)
plt.xlabel(r'$\frac{K_BT}{\hbar\omega}$',size=int(n/8*20))
plt.ylabel(r'$C_V^{cl}$',size=int(n/8*20))
plt.text(1.5,0.97,r'$\hbar=\omega=K_B=N=1$',size=int(n/8*20))
plt.savefig("cvcl.png",bbox_inches='tight')

# %%
def sq(x):
    return ((x + 1/2)*np.log(x + 1/2) - (x - 1/2)*np.log(x - 1/2))

# %%
def scl(x):
    return (1 + np.log(x))

# %%
x2 = np.linspace(1/2,3,500)
y5 = sq(x2)
y6 = scl(x2)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:2: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:2: RuntimeWarning: invalid value encountered in multiply
#   from ipykernel import kernelapp as app

# %%
plt.figure(figsize=(8,int(n*(5/8))))
plt.plot(x2,y5,c='r')
plt.title('Entropía Cuántica',size=int(n/8*20))
plt.xlim(1/2,3)
plt.xlabel(r'$\frac{\epsilon}{\hbar\omega}$',size=int(n/8*20))
plt.ylabel('s$_q$',size=int(n/8*20))
plt.text(1.5,0.4,r'$\hbar=\omega=K_B=N=1$',size=int(n/8*20))
plt.savefig("cvcl.png",bbox_inches='tight')

# %%
plt.figure(figsize=(8,int(n*(5/8))))
plt.plot(x2,y6,c='r')
plt.title('Entropía Clásica',size=int(n/8*20))
plt.xlim(1/2,3)
plt.xlabel(r'$\frac{\epsilon}{\hbar\omega}$',size=int(n/8*20))
plt.ylabel('s$_{cl}$',size=int(n/8*20))
plt.text(1.5,0.7,r'$\hbar=\omega=K_B=N=1$',size=int(n/8*20))
plt.savefig("cvcl.png",bbox_inches='tight')
